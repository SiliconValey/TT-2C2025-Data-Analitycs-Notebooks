# %% [markdown]
# <a href="https://colab.research.google.com/github/SiliconValey/TT-2C2025-Data-Analitycs-Notebooks/blob/main/Clase_1/Clase_1_Actividad_1_Lenguaje_Markup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividades

# %% [markdown]
# ```
# # Tiene formato de código
# ```
#
# ## Actividad 1

# %% [markdown]
#   Creá tu propio bloque de texto. Utiliza:
#   - formatos de texto
#   - links
#   - al menos una imagen de tu carpeta Drive

# %% [markdown]
# #Mi Bloque de Texto
#
# ##Formas de texto.
# **Negrita**
# *Cursiva*
#
# ##Links
# [Enlace a mi GitHub](https://github.com/SiliconValey?tab=repositories)
#
#
# ##Cargamos una imagen de mi GoogleDrive
#
# <img src="https://drive.google.com/uc?id=1QXSG5m8-d2DnpbbLIo1vwkoBXMA_ISCK">

# %% [markdown]
# ## Actividad 2

# %% [markdown]
# Creá un bloque de código con un programa que pida un número por teclado, y responda si es par o impar. Ejecutalo.

# %%
#Codigo en Python

numero = 12

if numero % 2 == 0:
  print(f"Numero {numero} es par.")
else:
  print(f"Numero {numero} es impar.")
# Out:
# Numero 12 es par.
